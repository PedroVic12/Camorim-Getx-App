# %% [markdown]
# 1- abre os 2 arquivos
#
# 2- pega as infos necessarias
#
# 3 - cria uma aba para cada barco
#
# 4 - preenche os dados para cada barco em cada aba
#
# 5 - coloca os dados fixos

# %%
import openpyxl
import pyautogui
import pandas as pd
PLANILHA = '../assets/EQUIPAMENTOS FROTA.xlsx'

def escreve_formulario(x,y,dados):
    pyautogui.click(x,y, duration = 0.5)
    pyautogui.write(dados)

def get_last_row(planilha):
    return planilha.max_row

def get_index(workbook):
    for index, sheet in enumerate(workbook, start=1):
        sheet.title = f'Aba{index}'


def get_cell(sheet,range):
    sheet[range].value 


def salvar(wb,name_xlsx):
    wb.save(f'{name_xlsx}.xlsx')
    print(f'Arquivo {name_xlsx} salvo!')

def copiar_aba(wb,nome_old,nome_new):
    sheet_to_copy = wb[nome_old]
    new_sheet = wb.create_sheet(nome_new)
    for row in sheet_to_copy.iter_rows():
        for cell in row:
            #rint(cell)
            new_sheet[cell.coordinate].value = cell.value


def copiar_excel(wb,new_sheet_name):
    source = wb.active
    target = wb.copy_worksheet(source)
    target.title = new_sheet_name
    
    salvar(wb,'copia_teste')

# %%
df_equipamentos = pd.read_excel(PLANILHA)
cols = df_equipamentos.columns[:4]

df = df_equipamentos[cols]
df
# Out:
#     EMBARCAÇÃO EQUIPAMENTO FABRICANTE       MODELO
# 0       C OURO         MCP        CAT        3516B
# 1       C OURO         MCP        CAT        3516B
# 2       C OURO         MCA        CAT        3406C
# 3       C OURO         MCA        CAT        3406C
# 4       C OURO    AZIMUTAL   SCHOTTEL  SRP 1215 CP
# ..         ...         ...        ...          ...
# 376       TITÃ   REVERSORA         ZF        W1900
# 377    ZANGADO         MCP     SCANIA    DS-11 MO1
# 378    ZANGADO         MCP     SCANIA    DS-11 MO1
# 379    ZANGADO   REVERSORA   REINTJES      WAV-121
# 380    ZANGADO   REVERSORA   REINTJES      WAV-121
#
# [381 rows x 4 columns]

# %%
nomes_barcos = list(df['EMBARCAÇÃO'].drop_duplicates())
print(nomes_barcos)

pivot = df.pivot_table(index = 'EMBARCAÇÃO', columns='EQUIPAMENTO',aggfunc='count')
#display(pivot)
# Out:
# ['C OURO', 'ATLANTICO', 'AÇU', 'ANGRA', 'ARRAIAL', 'MACAÉ', 'MACEIÓ', 'NITEROI', 'SALVADOR ', 'SEPETIBA', 'VITORIA', 'RIO', 'ITACURUÇA', 'SAGAMORIM II', 'LH COMANDANTE', 'SUPERPESA XIII', 'SUPERPESA XIV', 'ÁGATA', 'ESMERALDA', 'JADE', 'TOPAZIO', 'TURMALINA', 'TURQUESA', 'BRILHANTE', 'CRISTAL', 'DIAMANTE', 'QUARTZO', 'OPALA', 'PEROLA ', 'CICLONE', 'F. ANDREIS XI', 'MERLIM', 'NEBLINA', 'NEW TROVÃO', 'ONIX', 'PERSIVAL', 'TEMPESTADE', 'TORMENTA', 'TORNADO', 'TUFÃO', 'VENDAVAL', 'VENTANIA', 'VIGO MAXIMUS', 'COBRE', 'MERCURIO IV', 'NIQUEL', 'TEMPORAL', 'ADS I', 'CARLA', 'DIALCAR III', 'DIALCAR V', 'FELIZ', 'FLORA', 'MINI ORANGE', 'N.ALMEIDA VII', 'NAVEMAR XIV', 'PRUDENT', 'RELÂMPAGO', 'TITÃ', 'ZANGADO']

# %%
df_filtrado = df.loc[df['EMBARCAÇÃO']== nomes_barcos[6]]
df_filtrado
# Out:
#    EMBARCAÇÃO EQUIPAMENTO  FABRICANTE         MODELO
# 47     MACEIÓ         MCP  MITSUBISHI  S6R2-T2MPTK3L
# 48     MACEIÓ         MCP  MITSUBISHI  S6R2-T2MPTK3L
# 49     MACEIÓ         MCP  MITSUBISHI    S12R-T2MPTK
# 50     MACEIÓ         MCA         MWM          6.10T
# 51     MACEIÓ         MCA         MWM          6.10T
# 52     MACEIÓ   REVERSORA   TWIN DISC     MGX 5321DC
# 53     MACEIÓ   REVERSORA   TWIN DISC     MGX 5321DC
# 54     MACEIÓ   REVERSORA   TWIN DISC     MGX 5321DC

# %% [markdown]
# ## PLanilha 2
# ---

# %%
df_cadastro = pd.read_excel('../assets/Cadastro de Equipamentos - Oilxplorer Marine.xlsx',skiprows=6)
df_cadastro.head()
# Out:
#    Nº Descrição do Equipamento     Lubrificante em uso  \
# 0   1         MCP BB (EXAMPLE)  Mobil Delvac MX 15W-40
# 1   2                      NaN                     NaN
# 2   3                      NaN                     NaN
# 3   4                      NaN                     NaN
# 4   5                      NaN                     NaN
#
#   Fabricante do Equipamento Modelo do Equipamento  Vol. (L)  \
# 0               Caterpillar              CAT 3516     800.0
# 1                       NaN                   NaN       NaN
# 2                       NaN                   NaN       NaN
# 3                       NaN                   NaN       NaN
# 4                       NaN                   NaN       NaN
#
#    Periodicidade de coleta (dias)
# 0                            90.0
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %%
# Carregar a planilha
wb_marine = openpyxl.load_workbook('../assets/Cadastro de Equipamentos - Oilxplorer Marine.xlsx')
sheet = wb_marine['Plan1']  # Substitua pelo nome real da sua aba
nomes_sheets = wb_marine.sheetnames

#wb_marine.copy_worksheet(source_id=wb_marine['SEPETIBA'], target_id=wb_marine['Plan1'])

def colocarAbasArray(nomes_barcos)
    for n in nomes_barcos:
        wb_marine.create_sheet(title= n)
        wb_marine.save('../assets/Cadastro de Equipamentos - Oilxplorer Marine.xlsx')
        
print(wb_marine.sheetnames)
# Out:
# /home/pedrov/.local/lib/python3.11/site-packages/openpyxl/reader/drawings.py:29: UserWarning: DrawingML support is incomplete and limited to charts and images only. Shapes and drawings will be lost.
#   warn("DrawingML support is incomplete and limited to charts and images only. Shapes and drawings will be lost.")
# ['Plan1', 'C OURO', 'ATLANTICO', 'AÇU', 'ANGRA', 'ARRAIAL', 'MACAÉ', 'MACEIÓ', 'NITEROI', 'SALVADOR ', 'SEPETIBA', 'VITORIA', 'RIO', 'ITACURUÇA', 'SAGAMORIM II', 'LH COMANDANTE', 'SUPERPESA XIII', 'SUPERPESA XIV', 'ÁGATA', 'ESMERALDA', 'JADE', 'TOPAZIO', 'TURMALINA', 'TURQUESA', 'BRILHANTE', 'CRISTAL', 'DIAMANTE', 'QUARTZO', 'OPALA', 'PEROLA ', 'CICLONE', 'F. ANDREIS XI', 'MERLIM', 'NEBLINA', 'NEW TROVÃO', 'ONIX', 'PERSIVAL', 'TEMPESTADE', 'TORMENTA', 'TORNADO', 'TUFÃO', 'VENDAVAL', 'VENTANIA', 'VIGO MAXIMUS', 'COBRE', 'MERCURIO IV', 'NIQUEL', 'TEMPORAL', 'ADS I', 'CARLA', 'DIALCAR III', 'DIALCAR V', 'FELIZ', 'FLORA', 'MINI ORANGE', 'N.ALMEIDA VII', 'NAVEMAR XIV', 'PRUDENT', 'RELÂMPAGO', 'TITÃ', 'ZANGADO']

# %%
wb = openpyxl.load_workbook('./copia_teste.xlsx')



copiar_excel(wb,wb['AÇU'].title)
# Out:
# Arquivo copia_teste salvo!

# %%
wb_marine = openpyxl.load_workbook('../assets/Cadastro de Equipamentos - Oilxplorer Marine.xlsx')

for index in range(0,len(nomes_barcos) - 25):
    print(wb_marine.sheetnames[index+1])

    planilhas = wb_marine[wb_marine.sheetnames[index+1]]
    print(planilhas)
    print(nomes_barcos[index])        
    #wb_marine.save('teste_output.xlsx')
# Out:
# C OURO
# <Worksheet "C OURO">
# C OURO
# Arquivo copia_teste salvo!
# ATLANTICO
# <Worksheet "ATLANTICO">
# ATLANTICO
# Arquivo copia_teste salvo!
# AÇU
# <Worksheet "AÇU">
# AÇU
# Arquivo copia_teste salvo!
# ANGRA
# <Worksheet "ANGRA">
# ANGRA
# Arquivo copia_teste salvo!
# ARRAIAL
# <Worksheet "ARRAIAL">
# ARRAIAL
# Arquivo copia_teste salvo!
# MACAÉ
# <Worksheet "MACAÉ">
# MACAÉ
# Arquivo copia_teste salvo!
# MACEIÓ
# <Worksheet "MACEIÓ">
# MACEIÓ
# Arquivo copia_teste salvo!
# NITEROI
# <Worksheet "NITEROI">
# NITEROI
# Arquivo copia_teste salvo!
# SALVADOR
# <Worksheet "SALVADOR ">
# SALVADOR
# Arquivo copia_teste salvo!
# SEPETIBA
# <Worksheet "SEPETIBA">
# SEPETIBA
# Arquivo copia_teste salvo!
# VITORIA
# <Worksheet "VITORIA">
# VITORIA
# Arquivo copia_teste salvo!
# RIO
# <Worksheet "RIO">
# RIO
# Arquivo copia_teste salvo!
# ITACURUÇA
# <Worksheet "ITACURUÇA">
# ITACURUÇA
# Arquivo copia_teste salvo!
# SAGAMORIM II
# <Worksheet "SAGAMORIM II">
# SAGAMORIM II
# Arquivo copia_teste salvo!
# LH COMANDANTE
# <Worksheet "LH COMANDANTE">
# LH COMANDANTE
# Arquivo copia_teste salvo!
# SUPERPESA XIII
# <Worksheet "SUPERPESA XIII">
# SUPERPESA XIII
# Arquivo copia_teste salvo!
# SUPERPESA XIV
# <Worksheet "SUPERPESA XIV">
# SUPERPESA XIV
# Arquivo copia_teste salvo!
# ÁGATA
# <Worksheet "ÁGATA">
# ÁGATA
# Arquivo copia_teste salvo!
# ESMERALDA
# <Worksheet "ESMERALDA">
# ESMERALDA
# Arquivo copia_teste salvo!
# JADE
# <Worksheet "JADE">
# JADE
# Arquivo copia_teste salvo!
# TOPAZIO
# <Worksheet "TOPAZIO">
# TOPAZIO
# Arquivo copia_teste salvo!
# TURMALINA
# <Worksheet "TURMALINA">
# TURMALINA
# Arquivo copia_teste salvo!
# TURQUESA
# <Worksheet "TURQUESA">
# TURQUESA
# Arquivo copia_teste salvo!
# BRILHANTE
# <Worksheet "BRILHANTE">
# BRILHANTE
# Arquivo copia_teste salvo!
# CRISTAL
# <Worksheet "CRISTAL">
# CRISTAL
# Arquivo copia_teste salvo!
# DIAMANTE
# <Worksheet "DIAMANTE">
# DIAMANTE
# Arquivo copia_teste salvo!
# QUARTZO
# <Worksheet "QUARTZO">
# QUARTZO
# Arquivo copia_teste salvo!
# OPALA
# <Worksheet "OPALA">
# OPALA
# Arquivo copia_teste salvo!
# PEROLA
# <Worksheet "PEROLA ">
# PEROLA
# Arquivo copia_teste salvo!
# CICLONE
# <Worksheet "CICLONE">
# CICLONE
# Arquivo copia_teste salvo!
# F. ANDREIS XI
# <Worksheet "F. ANDREIS XI">
# F. ANDREIS XI
# Arquivo copia_teste salvo!
# MERLIM
# <Worksheet "MERLIM">
# MERLIM
# Arquivo copia_teste salvo!
# NEBLINA
# <Worksheet "NEBLINA">
# NEBLINA
# Arquivo copia_teste salvo!
# NEW TROVÃO
# <Worksheet "NEW TROVÃO">
# NEW TROVÃO
# Arquivo copia_teste salvo!
# ONIX
# <Worksheet "ONIX">
# ONIX
# Arquivo copia_teste salvo!

# %%
def preenche_dados(sheet,df):
    for row in df.iterrows():
        sheet[f'B{9 + index}'] = row['EQUIPAMENTO']
        sheet[f'D{9 + index}'] = row['FABRICANTE']
        sheet[f'E{9 + index}'] = row['MODELO']

for index in range(0,len(nomes_barcos)-45):
    try:
        planilhas = wb_marine[wb_marine.sheetnames[index+1]]

        #copiar_excel(wb_marine,nomes_barcos[index] )


        if (nomes_barcos[index] == planilhas.title ):
            planilhas['D5'].value = 'PV'
            planilhas['D3'].value = nomes_barcos[index]


  
        wb_marine.save('teste_output.xlsx')


    except IndexError:
        print("Erro")
        continue
# Out:
# Arquivo copia_teste salvo!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[399], line 11
#       8 try:
#       9     planilhas = wb_marine[wb_marine.sheetnames[index+1]]
# ---> 11     copiar_excel(wb_marine,nomes_barcos[index] )
#      14     if (nomes_barcos[index] == planilhas.title ):
#      15         planilhas['D5'].value = 'PV'
#
# Cell In[392], line 40, in copiar_excel(wb, new_sheet_name)
#      37 target = wb.copy_worksheet(source)
#      39 target.title = new_sheet_name
# ---> 40 salvar(wb,'copia_teste')
#
# Cell In[392], line 23, in salvar(wb, name_xlsx)
#      22 def salvar(wb,name_xlsx):
# ---> 23     wb.save(f'{name_xlsx}.xlsx')
#      24     print(f'Arquivo {name_xlsx} salvo!')
#
# File ~/.local/lib/python3.11/site-packages/openpyxl/workbook/workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File ~/.local/lib/python3.11/site-packages/openpyxl/writer/excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.utcnow()
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File ~/.local/lib/python3.11/site-packages/openpyxl/writer/excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File ~/.local/lib/python3.11/site-packages/openpyxl/writer/excel.py:77, in ExcelWriter.write_data(self)
#      74     custom_override = CustomOverride()
#      75     self.manifest.append(custom_override)
# ---> 77 self._write_worksheets()
#      78 self._write_chartsheets()
#      79 self._write_images()
#
# File ~/.local/lib/python3.11/site-packages/openpyxl/writer/excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File ~/.local/lib/python3.11/site-packages/openpyxl/writer/excel.py:200, in ExcelWriter.write_worksheet(self, ws)
#     198 else:
#     199     writer = WorksheetWriter(ws)
# --> 200     writer.write()
#     202 ws._rels = writer._rels
#     203 self._archive.write(writer.out, ws.path[1:])
#
# File ~/.local/lib/python3.11/site-packages/openpyxl/worksheet/_writer.py:358, in WorksheetWriter.write(self)
#     354 def write(self):
#     355     """
#     356     High level
#     357     """
# --> 358     self.write_top()
#     359     self.write_rows()
#     360     self.write_tail()
#
# File ~/.local/lib/python3.11/site-packages/openpyxl/worksheet/_writer.py:103, in WorksheetWriter.write_top(self)
#     101 self.write_views()
#     102 self.write_format()
# --> 103 self.write_cols()
#
# File ~/.local/lib/python3.11/site-packages/openpyxl/worksheet/_writer.py:87, in WorksheetWriter.write_cols(self)
#      85 def write_cols(self):
#      86     cols = self.ws.column_dimensions
# ---> 87     self.xf.send(cols.to_tree())
#
# File ~/.local/lib/python3.11/site-packages/openpyxl/worksheet/_writer.py:298, in WorksheetWriter.get_stream(self)
#     296             continue
#     297         else:
# --> 298             xf.write(el)
#     299 except GeneratorExit:
#     300     pass
#
# KeyboardInterrupt:

# %%
def ver_planilha(wk_name):
    for row in wk_name.iter_rows(values_only=True):
        print(row)

# %%
# Começar a escrever a partir da linha 9
start_row = 9
for index, row in df.iterrows():
    # Escrevendo os dados nas células correspondentes
    sheet[f'B{start_row + index}'] = row['EQUIPAMENTO']
    sheet[f'D{start_row + index}'] = row['FABRICANTE']
    sheet[f'E{start_row + index}'] = row['MODELO']
    #sheet['D3'].value = nomes_barcos[index]

    


# Salvar a planilha
wb_marine.save('output.xlsx',)

# %%
def roboPreencheCadastro(PLANILHA):

    workbook = openpyxl.load_workbook(PLANILHA)
    planilha = workbook['OverView IFS']
    _array = []

    lastRow = get_last_row(planilha)

    for row in planilha.iter_rows(min_row = 2,max_row=6):

        # COluna1 , Coluna 2, Coluna 3
        equipamento = row[1].value
        print(equipamento)
        escreve_formulario(1149,178,equipamento)

        rebocador = row[0].value
        escreve_formulario(1150,246,rebocador)

        acao = row[2].value
        escreve_formulario(1150,323,acao)

        status = row[3].value
        escreve_formulario(1150,370,status)

        tipo = row[4].value
        escreve_formulario(1160,467,tipo)

        pyautogui.click(1319,724)
